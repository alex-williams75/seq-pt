# %% [markdown]
# # Machine Learning for Prediciton of Bus Stop Demand
# This follows on from the SEQ analysis notebook found in this Github directory.

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import matplotlib.pyplot as plt

df = pd.read_csv('./data/ML_data.csv', index_col=0)

# %% [markdown]
# # Preprocessing

# %%
# Get features and target
X = df.drop(['quantity_class'], axis=1)
y = df['quantity_class']

# %%
# Separate features for scaling
scale_list = ['frequency', 'Median_age_persons', 'Med_mort_repaymnt_monthly', 'Median_rent_weekly', 'Med_tot_hh_incom_weekly', 'Average_household_size']
X_scale = X[scale_list]
X_no_scale = X.drop(scale_list, axis=1)

# Split  data into training and testing sets
X_train_scale, X_test_scale, X_train_no_scale, X_test_no_scale, y_train, y_test = train_test_split(X_scale, X_no_scale, y, test_size=0.2, random_state=12)

# Scale features
scaler = StandardScaler()
X_train_scaled = pd.concat([pd.DataFrame(scaler.fit_transform(X_train_scale), columns=scale_list, index=X_train_scale.index), X_train_no_scale], axis=1)
X_test_scaled = pd.concat([pd.DataFrame(scaler.transform(X_test_scale), columns=scale_list, index=X_test_scale.index), X_test_no_scale], axis=1)

# %%
# Encode target

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %% [markdown]
# # Model Without Cross Validation or Tuning
# As shown, running a model without cross validation or tuning results in a low accuracy.

# %%
# Establish XGBoost model
model = xgb.XGBClassifier()

# Fit the model
model.fit(X_train_scaled, y_train_encoded)
# Undertake predictions
predictions = model.predict(X_test_scaled)

# %%
# Evaluate accuracy
accuracy = accuracy_score(y_test_encoded, predictions)
print(f'Accuracy: {accuracy:.2f}')

# Display confusion matrix
conf_matrix = confusion_matrix(y_test_encoded, predictions)
print('Confusion Matrix:')
print(conf_matrix)

# Display classification report
class_report = classification_report(y_test_encoded, predictions)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.50
# Confusion Matrix:
# [[185  13  46  12]
#  [ 32 106  71  84]
#  [ 70  53 105  46]
#  [ 14  71  42 162]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.61      0.72      0.66       256
#            1       0.44      0.36      0.40       293
#            2       0.40      0.38      0.39       274
#            3       0.53      0.56      0.55       289
#
#     accuracy                           0.50      1112
#    macro avg       0.50      0.51      0.50      1112
# weighted avg       0.49      0.50      0.50      1112

# %% [markdown]
# # Model with Cross Validation and Tuning
# Performing a grid search with the specified parameters...

# %%
# Assuming X_train_scaled, y_train_encoded are your training data
rand_param = {
    'learning_rate': np.arange(0.01, 0.50, 0.01),
    'max_depth': np.arange(3, 6, 1),
    'subsample': np.arange(0.2, 1.0, 0.05),
    'colsample_bytree': np.arange(0.2, 1.0, 0.05)
}

rand_search = RandomizedSearchCV(estimator=model, param_distributions=rand_param, n_iter=300, scoring='accuracy', cv=5, verbose=2)
rand_search.fit(X_train_scaled, y_train_encoded)

best_params = rand_search.best_params_
best_model = rand_search.best_estimator_
feature_importance = best_model.feature_importances_
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.09, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.09, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.09, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.09, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.09, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.33, max_depth=4, subsample=0.49999999999999994; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.33, max_depth=4, subsample=0.49999999999999994; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.33, max_depth=4, subsample=0.49999999999999994; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.33, max_depth=4, subsample=0.49999999999999994; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.33, max_depth=4, subsample=0.49999999999999994; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.45, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.45, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.45, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.45, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.45, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.4, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.4, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.4, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.4, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.4, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.19, max_depth=5, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.19, max_depth=5, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.19, max_depth=5, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.19, max_depth=5, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.19, max_depth=5, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.7499999999999998, learning_rate=0.22, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.7499999999999998, learning_rate=0.22, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.7499999999999998, learning_rate=0.22, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.7499999999999998, learning_rate=0.22, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.7499999999999998, learning_rate=0.22, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, subsample=0.8999999999999999; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=5, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.01, max_depth=5, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.01, max_depth=5, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.01, max_depth=5, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.01, max_depth=5, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.01, max_depth=5, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.27, max_depth=3, subsample=0.39999999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.27, max_depth=3, subsample=0.39999999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.27, max_depth=3, subsample=0.39999999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.27, max_depth=3, subsample=0.39999999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.27, max_depth=3, subsample=0.39999999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.23, max_depth=4, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.23, max_depth=4, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.23, max_depth=4, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.23, max_depth=4, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.23, max_depth=4, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.39, max_depth=5, subsample=0.8999999999999999; total time=   0.3s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.39, max_depth=5, subsample=0.8999999999999999; total time=   0.3s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.39, max_depth=5, subsample=0.8999999999999999; total time=   0.3s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.39, max_depth=5, subsample=0.8999999999999999; total time=   0.3s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.39, max_depth=5, subsample=0.8999999999999999; total time=   0.3s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.34, max_depth=5, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.34, max_depth=5, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.34, max_depth=5, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.34, max_depth=5, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.34, max_depth=5, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.47000000000000003, max_depth=4, subsample=0.39999999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.47000000000000003, max_depth=4, subsample=0.39999999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.47000000000000003, max_depth=4, subsample=0.39999999999999997; total time=   0.3s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.47000000000000003, max_depth=4, subsample=0.39999999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.47000000000000003, max_depth=4, subsample=0.39999999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.26, max_depth=5, subsample=0.49999999999999994; total time=   0.3s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.26, max_depth=5, subsample=0.49999999999999994; total time=   0.3s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.26, max_depth=5, subsample=0.49999999999999994; total time=   0.3s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.26, max_depth=5, subsample=0.49999999999999994; total time=   0.3s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.26, max_depth=5, subsample=0.49999999999999994; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.36000000000000004, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.36000000000000004, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.36000000000000004, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.36000000000000004, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.36000000000000004, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.42000000000000004, max_depth=3, subsample=0.44999999999999996; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.42000000000000004, max_depth=3, subsample=0.44999999999999996; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.42000000000000004, max_depth=3, subsample=0.44999999999999996; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.42000000000000004, max_depth=3, subsample=0.44999999999999996; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.42000000000000004, max_depth=3, subsample=0.44999999999999996; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.3, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.3, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.3, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.3, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.3, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.23, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.23, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.23, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.23, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.23, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.24000000000000002, max_depth=5, subsample=0.6499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.24000000000000002, max_depth=5, subsample=0.6499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.24000000000000002, max_depth=5, subsample=0.6499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.24000000000000002, max_depth=5, subsample=0.6499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.24000000000000002, max_depth=5, subsample=0.6499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.7499999999999998, learning_rate=0.38, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7499999999999998, learning_rate=0.38, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7499999999999998, learning_rate=0.38, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7499999999999998, learning_rate=0.38, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7499999999999998, learning_rate=0.38, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.02, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.02, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.02, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.02, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.02, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.15000000000000002, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.15000000000000002, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.15000000000000002, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.15000000000000002, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.15000000000000002, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.09999999999999999, max_depth=4, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.09999999999999999, max_depth=4, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.09999999999999999, max_depth=4, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.09999999999999999, max_depth=4, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.09999999999999999, max_depth=4, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.14, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.14, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.14, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.14, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.14, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.27, max_depth=3, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.27, max_depth=3, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.27, max_depth=3, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.27, max_depth=3, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.27, max_depth=3, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.2, max_depth=5, subsample=0.35; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.2, max_depth=5, subsample=0.35; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.2, max_depth=5, subsample=0.35; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.2, max_depth=5, subsample=0.35; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.2, max_depth=5, subsample=0.35; total time=   0.2s
# [CV] END colsample_bytree=0.25, learning_rate=0.01, max_depth=3, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.01, max_depth=3, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.01, max_depth=3, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.01, max_depth=3, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.01, max_depth=3, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.04, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.04, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.04, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.04, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.04, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.25, learning_rate=0.03, max_depth=3, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.03, max_depth=3, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.03, max_depth=3, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.03, max_depth=3, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.03, max_depth=3, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.13, max_depth=5, subsample=0.35; total time=   0.2s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.13, max_depth=5, subsample=0.35; total time=   0.2s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.13, max_depth=5, subsample=0.35; total time=   0.2s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.13, max_depth=5, subsample=0.35; total time=   0.2s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.13, max_depth=5, subsample=0.35; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.060000000000000005, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.060000000000000005, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.060000000000000005, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.060000000000000005, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.060000000000000005, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.05, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.05, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.05, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.05, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.05, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.21000000000000002, max_depth=4, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.21000000000000002, max_depth=4, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.21000000000000002, max_depth=4, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.21000000000000002, max_depth=4, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.21000000000000002, max_depth=4, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.04, max_depth=4, subsample=0.39999999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.04, max_depth=4, subsample=0.39999999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.04, max_depth=4, subsample=0.39999999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.04, max_depth=4, subsample=0.39999999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.04, max_depth=4, subsample=0.39999999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.25, max_depth=4, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.25, max_depth=4, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.25, max_depth=4, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.25, max_depth=4, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.25, max_depth=4, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.22, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.22, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.22, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.22, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.22, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.02, max_depth=5, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.02, max_depth=5, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.02, max_depth=5, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.02, max_depth=5, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.02, max_depth=5, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.28, max_depth=4, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.28, max_depth=4, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.28, max_depth=4, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.28, max_depth=4, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.28, max_depth=4, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.060000000000000005, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.060000000000000005, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.060000000000000005, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.060000000000000005, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.060000000000000005, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.05, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.05, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.05, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.05, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.05, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.45, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.45, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.45, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.45, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.45, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.43, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.43, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.43, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.43, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.43, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.06999999999999999, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.06999999999999999, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.06999999999999999, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.06999999999999999, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.06999999999999999, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.41000000000000003, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.41000000000000003, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.41000000000000003, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.41000000000000003, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.41000000000000003, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.45, max_depth=5, subsample=0.9499999999999997; total time=   0.3s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.45, max_depth=5, subsample=0.9499999999999997; total time=   0.3s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.45, max_depth=5, subsample=0.9499999999999997; total time=   0.3s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.45, max_depth=5, subsample=0.9499999999999997; total time=   0.3s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.45, max_depth=5, subsample=0.9499999999999997; total time=   0.3s
# [CV] END colsample_bytree=0.2, learning_rate=0.44, max_depth=5, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.44, max_depth=5, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.44, max_depth=5, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.44, max_depth=5, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.44, max_depth=5, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.25, max_depth=5, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.25, max_depth=5, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.25, max_depth=5, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.25, max_depth=5, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.25, max_depth=5, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.13, max_depth=5, subsample=0.49999999999999994; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.13, max_depth=5, subsample=0.49999999999999994; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.13, max_depth=5, subsample=0.49999999999999994; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.13, max_depth=5, subsample=0.49999999999999994; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.13, max_depth=5, subsample=0.49999999999999994; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.44, max_depth=4, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.44, max_depth=4, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.44, max_depth=4, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.44, max_depth=4, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.44, max_depth=4, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.39, max_depth=5, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.39, max_depth=5, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.39, max_depth=5, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.39, max_depth=5, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.39, max_depth=5, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.21000000000000002, max_depth=5, subsample=0.25; total time=   0.2s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.21000000000000002, max_depth=5, subsample=0.25; total time=   0.2s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.21000000000000002, max_depth=5, subsample=0.25; total time=   0.2s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.21000000000000002, max_depth=5, subsample=0.25; total time=   0.2s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.21000000000000002, max_depth=5, subsample=0.25; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.37, max_depth=3, subsample=0.8499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.37, max_depth=3, subsample=0.8499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.37, max_depth=3, subsample=0.8499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.37, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.37, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.29000000000000004, max_depth=3, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.29000000000000004, max_depth=3, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.29000000000000004, max_depth=3, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.29000000000000004, max_depth=3, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.29000000000000004, max_depth=3, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.04, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.04, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.04, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.04, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.04, max_depth=5, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.33, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.33, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.33, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.33, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.33, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.29000000000000004, max_depth=4, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.29000000000000004, max_depth=4, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.29000000000000004, max_depth=4, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.29000000000000004, max_depth=4, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.29000000000000004, max_depth=4, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.33, max_depth=4, subsample=0.5999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.33, max_depth=4, subsample=0.5999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.33, max_depth=4, subsample=0.5999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.33, max_depth=4, subsample=0.5999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.33, max_depth=4, subsample=0.5999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.2, learning_rate=0.21000000000000002, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.21000000000000002, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.21000000000000002, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.21000000000000002, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.21000000000000002, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.44, max_depth=3, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.44, max_depth=3, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.44, max_depth=3, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.44, max_depth=3, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.44, max_depth=3, subsample=0.3; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.12, max_depth=4, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.12, max_depth=4, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.12, max_depth=4, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.12, max_depth=4, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.12, max_depth=4, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.2, max_depth=4, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.2, max_depth=4, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.2, max_depth=4, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.2, max_depth=4, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.2, max_depth=4, subsample=0.8999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.46, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.46, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.46, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.46, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.46, max_depth=5, subsample=0.25; total time=   0.1s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.44, max_depth=4, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.44, max_depth=4, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.44, max_depth=4, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.44, max_depth=4, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.44, max_depth=4, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.3, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.3, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.3, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.3, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.3, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.06999999999999999, max_depth=3, subsample=0.6499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.06999999999999999, max_depth=3, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.06999999999999999, max_depth=3, subsample=0.6499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.06999999999999999, max_depth=3, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.06999999999999999, max_depth=3, subsample=0.6499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.35, learning_rate=0.2, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.35, learning_rate=0.2, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.35, learning_rate=0.2, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.35, learning_rate=0.2, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.35, learning_rate=0.2, max_depth=5, subsample=0.7499999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.2, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.2, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.2, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.2, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.2, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.48000000000000004, max_depth=4, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.48000000000000004, max_depth=4, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.48000000000000004, max_depth=4, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.48000000000000004, max_depth=4, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.48000000000000004, max_depth=4, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.08, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.08, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.08, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.08, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.08, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.31, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.31, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.31, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.31, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.31, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.36000000000000004, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.36000000000000004, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.36000000000000004, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.36000000000000004, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.5999999999999999, learning_rate=0.36000000000000004, max_depth=3, subsample=0.35; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.22, max_depth=4, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.22, max_depth=4, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.22, max_depth=4, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.22, max_depth=4, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.22, max_depth=4, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.45, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.45, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.45, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.45, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.45, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.22, max_depth=3, subsample=0.8999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.22, max_depth=3, subsample=0.8999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.22, max_depth=3, subsample=0.8999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.22, max_depth=3, subsample=0.8999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.22, max_depth=3, subsample=0.8999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.29000000000000004, max_depth=3, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.29000000000000004, max_depth=3, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.29000000000000004, max_depth=3, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.29000000000000004, max_depth=3, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.29000000000000004, max_depth=3, subsample=0.5999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.17, max_depth=4, subsample=0.8999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.17, max_depth=4, subsample=0.8999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.17, max_depth=4, subsample=0.8999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.17, max_depth=4, subsample=0.8999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.17, max_depth=4, subsample=0.8999999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.35000000000000003, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.35000000000000003, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.35000000000000003, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.35000000000000003, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.35000000000000003, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.05, max_depth=5, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.25, learning_rate=0.05, max_depth=5, subsample=0.44999999999999996; total time=   0.2s
# [CV] END colsample_bytree=0.25, learning_rate=0.05, max_depth=5, subsample=0.44999999999999996; total time=   0.2s
# ...
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.28, max_depth=4, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.44999999999999996, learning_rate=0.28, max_depth=4, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.42000000000000004, max_depth=5, subsample=0.39999999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.42000000000000004, max_depth=5, subsample=0.39999999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.42000000000000004, max_depth=5, subsample=0.39999999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.42000000000000004, max_depth=5, subsample=0.39999999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.8999999999999999, learning_rate=0.42000000000000004, max_depth=5, subsample=0.39999999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.25, learning_rate=0.47000000000000003, max_depth=4, subsample=0.7499999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.47000000000000003, max_depth=4, subsample=0.7499999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.47000000000000003, max_depth=4, subsample=0.7499999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.47000000000000003, max_depth=4, subsample=0.7499999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.47000000000000003, max_depth=4, subsample=0.7499999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.29000000000000004, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.29000000000000004, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.29000000000000004, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.29000000000000004, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.29000000000000004, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.25, learning_rate=0.35000000000000003, max_depth=4, subsample=0.7499999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.35000000000000003, max_depth=4, subsample=0.7499999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.35000000000000003, max_depth=4, subsample=0.7499999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.35000000000000003, max_depth=4, subsample=0.7499999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.35000000000000003, max_depth=4, subsample=0.7499999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.19, max_depth=5, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.19, max_depth=5, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.19, max_depth=5, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.19, max_depth=5, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.19, max_depth=5, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.49, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.49, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.49, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.49, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.25, learning_rate=0.49, max_depth=3, subsample=0.8499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.19, max_depth=3, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.19, max_depth=3, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.19, max_depth=3, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.19, max_depth=3, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.19, max_depth=3, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.18000000000000002, max_depth=5, subsample=0.7999999999999998; total time=   0.3s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.18000000000000002, max_depth=5, subsample=0.7999999999999998; total time=   0.3s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.18000000000000002, max_depth=5, subsample=0.7999999999999998; total time=   0.3s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.18000000000000002, max_depth=5, subsample=0.7999999999999998; total time=   0.3s
# [CV] END colsample_bytree=0.7999999999999998, learning_rate=0.18000000000000002, max_depth=5, subsample=0.7999999999999998; total time=   0.3s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.43, max_depth=4, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.43, max_depth=4, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.43, max_depth=4, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.43, max_depth=4, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.43, max_depth=4, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.17, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.17, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.17, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.17, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.17, max_depth=5, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.12, max_depth=3, subsample=0.2; total time=   0.0s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.12, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.12, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.12, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.12, max_depth=3, subsample=0.2; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.18000000000000002, max_depth=3, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.18000000000000002, max_depth=3, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.18000000000000002, max_depth=3, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.18000000000000002, max_depth=3, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.35, learning_rate=0.18000000000000002, max_depth=3, subsample=0.6499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.11, max_depth=3, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.11, max_depth=3, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.11, max_depth=3, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.11, max_depth=3, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.11, max_depth=3, subsample=0.9499999999999997; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.02, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.02, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.02, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.02, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.02, max_depth=4, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.35, learning_rate=0.15000000000000002, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.35, learning_rate=0.15000000000000002, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.35, learning_rate=0.15000000000000002, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.35, learning_rate=0.15000000000000002, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.35, learning_rate=0.15000000000000002, max_depth=5, subsample=0.7999999999999998; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.49, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.49, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.49, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.49, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.49, max_depth=3, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.25, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.25, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.25, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.25, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.5499999999999999, learning_rate=0.25, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.060000000000000005, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.060000000000000005, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.060000000000000005, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.060000000000000005, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.060000000000000005, max_depth=3, subsample=0.7999999999999998; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.37, max_depth=5, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.37, max_depth=5, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.37, max_depth=5, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.37, max_depth=5, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.37, max_depth=5, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.01, max_depth=5, subsample=0.25; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.01, max_depth=5, subsample=0.25; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.01, max_depth=5, subsample=0.25; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.01, max_depth=5, subsample=0.25; total time=   0.2s
# [CV] END colsample_bytree=0.6499999999999999, learning_rate=0.01, max_depth=5, subsample=0.25; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.33, max_depth=4, subsample=0.5999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.33, max_depth=4, subsample=0.5999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.33, max_depth=4, subsample=0.5999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.33, max_depth=4, subsample=0.5999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.8499999999999999, learning_rate=0.33, max_depth=4, subsample=0.5999999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.35000000000000003, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.35000000000000003, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.35000000000000003, max_depth=3, subsample=0.5499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.35000000000000003, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.9499999999999997, learning_rate=0.35000000000000003, max_depth=3, subsample=0.5499999999999999; total time=   0.1s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.18000000000000002, max_depth=5, subsample=0.6499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.18000000000000002, max_depth=5, subsample=0.6499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.18000000000000002, max_depth=5, subsample=0.6499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.18000000000000002, max_depth=5, subsample=0.6499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.49999999999999994, learning_rate=0.18000000000000002, max_depth=5, subsample=0.6499999999999999; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.3, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.3, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.3, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.3, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.3, max_depth=4, subsample=0.9499999999999997; total time=   0.2s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.39, max_depth=3, subsample=0.49999999999999994; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.39, max_depth=3, subsample=0.49999999999999994; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.39, max_depth=3, subsample=0.49999999999999994; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.39, max_depth=3, subsample=0.49999999999999994; total time=   0.1s
# [CV] END colsample_bytree=0.39999999999999997, learning_rate=0.39, max_depth=3, subsample=0.49999999999999994; total time=   0.1s

# %%
print(best_params)
print(best_model)
print(feature_importance)
# Out:
# {'subsample': 0.9499999999999997, 'max_depth': 5, 'learning_rate': 0.43, 'colsample_bytree': 0.8999999999999999}
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8999999999999999, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.43, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)
# [0.25611743 0.10021389 0.09333743 0.09617814 0.10145359 0.14403188
#  0.10811906 0.10054859]

# %%
# Plotting feature importance
feature_names = X_train_scaled.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
# print(feature_importance_df)

plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Importance')
plt.title('Feature Importance')
plt.show()

# %%
# Set up parameters
grid_param = {'learning_rate': [0.3, 0.35, 0.4],
          'max_depth': [5],
          'subsample': [0.85, 0.9, 0.95],
          'colsample_bytree': [0.9, 0.95]}

# Run model
grid_search = GridSearchCV(estimator=model, param_grid=grid_param, scoring='accuracy', cv=5, verbose=2)
grid_search.fit(X_train_scaled, y_train_encoded)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.35, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.4, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.3, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.35, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.85; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.95; total time=   0.3s
# [CV] END colsample_bytree=0.95, learning_rate=0.4, max_depth=5, subsample=0.95; total time=   0.3s

# %%
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_
print(best_params)
print(best_model)
# Out:
# {'colsample_bytree': 0.9, 'learning_rate': 0.3, 'max_depth': 5, 'subsample': 0.9}
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
best_model = xgb.XGBClassifier(colsample_bytree=0.9, learning_rate=0.3, max_depth=5, subsample=0.9)
best_model.fit(X_train_scaled, y_train_encoded)
predictions = best_model.predict(X_test_scaled)

# %%
# Evaluate accuracy
accuracy = accuracy_score(y_test_encoded, predictions)
print(f'Accuracy: {accuracy:.2f}')

# Display confusion matrix
conf_matrix = confusion_matrix(y_test_encoded, predictions)
print('Confusion Matrix:')
print(conf_matrix)

# Display classification report
class_report = classification_report(y_test_encoded, predictions)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.49
# Confusion Matrix:
# [[180   7  55  14]
#  [ 37  94  80  82]
#  [ 71  51 107  45]
#  [ 18  69  41 161]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.70      0.64       256
#            1       0.43      0.32      0.37       293
#            2       0.38      0.39      0.38       274
#            3       0.53      0.56      0.54       289
#
#     accuracy                           0.49      1112
#    macro avg       0.48      0.49      0.48      1112
# weighted avg       0.48      0.49      0.48      1112
